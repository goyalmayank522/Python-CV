# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
flat_chess=cv2.imread('flat_chess.jpg')
flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

real_chess=cv2.imread('real_chess.png')
real_chess=cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

gray_flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)
gray_real_chess=cv2.cvtColor(real_chess,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Detection using corner Harris method

# %% [markdown]
# ### FLAT CHESS

# %%
gray1=np.float32(gray_flat_chess)
dst1=cv2.cornerHarris(src=gray1,blockSize=2,ksize=3,k=0.04)
dst1=cv2.dilate(dst1,None)
flat_chess[dst1>0.01*dst1.max()]=(255,0,0)
plt.imshow(flat_chess)

# %% [markdown]
# ### REAL CHESS

# %%
gray2=np.float32(gray_real_chess)
dst2=cv2.cornerHarris(src=gray2,blockSize=2,ksize=3,k=0.04)
dst2=cv2.dilate(dst2,None)
real_chess[dst2>0.01*dst2.max()]=(255,0,0)
plt.imshow(real_chess)

# %% [markdown]
# # Detection using Shi-Tomasi method

# %% [markdown]
# ### FLAT CHESS

# %%
corners1=cv2.goodFeaturesToTrack(gray_flat_chess,85,0.01,10)
corners1=np.int0(corners1)
for i in corners1:
    x,y=i.ravel()
    cv2.circle(flat_chess,(x,y),5,(255,0,0),-1)
plt.imshow(flat_chess)

# %% [markdown]
# ### REAL CHESS

# %%
corners2=cv2.goodFeaturesToTrack(gray_real_chess,95,0.01,10)
corners2=np.int0(corners2)
for i in corners2:
    x,y=i.ravel()
    cv2.circle(real_chess,(x,y),5,(255,0,0),-1)
plt.imshow(real_chess)
